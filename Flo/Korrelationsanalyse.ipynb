# %%
import pandas as pd
import seaborn as sns

# %%
df_org_data = pd.read_parquet("escooter_copy.parquet")

# %%
df_org_data.holiday = df_org_data.holiday.astype(bool)
df_org_data.workingday = df_org_data.workingday.astype(bool)
df_org_data.loc[df_org_data.temp >45, "temp"] = df_org_data.temp.div(100)

# %%
df = df_org_data.copy()

# %%
df
# Out:
#                    datetime  holiday  workingday            weather   temp  \
# 0       2020-01-04 00:00:09    False       False  clear, few clouds   9.84
# 1       2020-01-04 00:00:41    False       False  clear, few clouds   9.84
# 2       2020-01-04 00:01:20    False       False  clear, few clouds   9.84
# 3       2020-01-04 00:04:12    False       False  clear, few clouds   9.84
# 4       2020-01-04 00:15:19    False       False  clear, few clouds   9.84
# ...                     ...      ...         ...                ...    ...
# 3755410 2022-01-03 23:58:10    False        True  clear, few clouds  10.66
# 3755411 2022-01-03 23:58:28    False        True  clear, few clouds  10.66
# 3755412 2022-01-03 23:58:46    False        True  clear, few clouds  10.66
# 3755413 2022-01-03 23:59:16    False        True  clear, few clouds  10.66
# 3755414 2022-01-03 23:59:48    False        True  clear, few clouds  10.66
#
#           atemp  humidity  windspeed  registered_customer
# 0        14.395      81.0     0.0000                 True
# 1        14.395      81.0     0.0000                 True
# 2        14.395      81.0     0.0000                 True
# 3        14.395      81.0     0.0000                 True
# 4        14.395      81.0     0.0000                 True
# ...         ...       ...        ...                  ...
# 3755410  13.635      65.0     8.9981                 True
# 3755411  13.635      65.0     8.9981                 True
# 3755412  13.635      65.0     8.9981                 True
# 3755413  13.635      65.0     8.9981                 True
# 3755414  13.635      65.0     8.9981                 True
#
# [3755415 rows x 9 columns]

# %%
df.corr().round(2)
# Out:
#                      holiday  workingday  temp  atemp  humidity  windspeed  \
# holiday                 1.00       -0.25  0.02   0.02      0.01      -0.01
# workingday             -0.25        1.00 -0.01  -0.01      0.05      -0.02
# temp                    0.02       -0.01  1.00   0.98     -0.18       0.01
# atemp                   0.02       -0.01  0.98   1.00     -0.15      -0.02
# humidity                0.01        0.05 -0.18  -0.15      1.00      -0.27
# windspeed              -0.01       -0.02  0.01  -0.02     -0.27       1.00
# registered_customer    -0.03        0.21 -0.13  -0.13      0.09      -0.02
#
#                      registered_customer
# holiday                            -0.03
# workingday                          0.21
# temp                               -0.13
# atemp                              -0.13
# humidity                            0.09
# windspeed                          -0.02
# registered_customer                 1.00

# %%
df.corr().round(2).to_clipboard()

# %%
sns.heatmap(df.corr().round(2), cmap= "Greens")
# Out:
# <AxesSubplot:>
