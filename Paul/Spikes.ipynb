# %%
import pandas as pd
import plotly.express as px
import numpy as np
import missingno as msn
import datetime
from pandas_profiling import ProfileReport
import sklearn

# %%
df = pd.read_parquet("escooter_history_2022.parquet")

# %%
df_2 = df.groupby(pd.Grouper(key="datetime",freq="W")).agg({"registered_customer": "count"}).reset_index()

# %%
df_2
# Out:
#       datetime  registered_customer
# 0   2020-01-05                 1786
# 1   2020-01-12                 9408
# 2   2020-01-19                 9025
# 3   2020-01-26                 7784
# 4   2020-02-02                10340
# ..         ...                  ...
# 101 2021-12-12                41785
# 102 2021-12-19                35966
# 103 2021-12-26                31871
# 104 2022-01-02                32812
# 105 2022-01-09                 6302
#
# [106 rows x 2 columns]

# %%
px.line(df_2,x="datetime",y="registered_customer")

# %%
px.scatter(df_2,x="datetime",y="registered_customer",color=df_2.datetime.dt.day,trendline="lowess")

# %%
df_2[df_2.datetime == "6-1-2020"]
# Out:
# Empty DataFrame
# Columns: [datetime, registered_customer]
# Index: []

# %%
df[df.datetime.between("2020-1-6", "2020-1-7")]
# Out:
#                 datetime  holiday  workingday            weather  temp  \
# 1786 2020-01-06 00:00:11      0.0         1.0  clear, few clouds  9.02
# 1787 2020-01-06 00:10:33      0.0         1.0  clear, few clouds  9.02
# 1788 2020-01-06 00:23:23      0.0         1.0  clear, few clouds  9.02
# 1789 2020-01-06 00:25:24      0.0         1.0  clear, few clouds  9.02
# 1790 2020-01-06 00:31:38      0.0         1.0  clear, few clouds  9.02
# ...                  ...      ...         ...                ...   ...
# 3130 2020-01-06 23:40:01      0.0         1.0  clear, few clouds  7.38
# 3131 2020-01-06 23:41:54      0.0         1.0  clear, few clouds  7.38
# 3132 2020-01-06 23:46:43      0.0         1.0  clear, few clouds  7.38
# 3133 2020-01-06 23:48:26      0.0         1.0  clear, few clouds  7.38
# 3134 2020-01-06 23:59:34      0.0         1.0  clear, few clouds  7.38
#
#        atemp  humidity  windspeed  registered_customer
# 1786   9.850      44.0    23.9994                 True
# 1787   9.850      44.0    23.9994                 True
# 1788   9.850      44.0    23.9994                 True
# 1789   9.850      44.0    23.9994                 True
# 1790   9.850      44.0    23.9994                 True
# ...      ...       ...        ...                  ...
# 3130  10.605      55.0     7.0015                 True
# 3131  10.605      55.0     7.0015                 True
# 3132  10.605      55.0     7.0015                 True
# 3133  10.605      55.0     7.0015                 True
# 3134  10.605      55.0     7.0015                 True
#
# [1349 rows x 9 columns]

# %%
df[df.datetime.between("2021-3-31", "2021-4-1")]
# Out:
#                    datetime  holiday  workingday            weather   temp  \
# 1777813 2021-03-31 00:00:08      0.0         1.0  clear, few clouds  14.76
# 1777814 2021-03-31 00:01:25      0.0         1.0  clear, few clouds  14.76
# 1777815 2021-03-31 00:02:52      0.0         1.0  clear, few clouds  14.76
# 1777816 2021-03-31 00:03:06      0.0         1.0  clear, few clouds  14.76
# 1777817 2021-03-31 00:03:09      0.0         1.0  clear, few clouds  14.76
# ...                     ...      ...         ...                ...    ...
# 1789707 2021-03-31 23:58:43      0.0         1.0  clear, few clouds  22.14
# 1789708 2021-03-31 23:58:52      0.0         1.0  clear, few clouds  22.14
# 1789709 2021-03-31 23:58:54      0.0         1.0  clear, few clouds  22.14
# 1789710 2021-03-31 23:59:16      0.0         1.0  clear, few clouds  22.14
# 1789711 2021-03-31 23:59:40      0.0         1.0  clear, few clouds  22.14
#
#           atemp  humidity  windspeed  registered_customer
# 1777813  17.425      37.0    12.9980                 True
# 1777814  17.425      37.0    12.9980                 True
# 1777815  16.665      40.0    19.0012                 True
# 1777816  16.665      40.0    19.0012                 True
# 1777817  16.665      40.0    19.0012                 True
# ...         ...       ...        ...                  ...
# 1789707  25.760      68.0     8.9981                 True
# 1789708  25.760      68.0     8.9981                 True
# 1789709  25.760      68.0     8.9981                 True
# 1789710  25.760      68.0     8.9981                 True
# 1789711  25.760      68.0     8.9981                 True
#
# [11899 rows x 9 columns]

# %%
df_5 = df[df.datetime.between("2021-4-14", "2021-4-15")]

# %%
df_5.temp.unique()
# Out:
# array([13.94, 13.12, 12.3 , 11.48, 15.58, 14.76, 16.4 , 18.04, 17.22])

# %%
df_3 = df.groupby(pd.Grouper(key="datetime",freq="W")).agg({"registered_customer": ("count","sum")}).reset_index()

# %%
df_3.columns = ["datetime","Anzahl","Anzahl_registered"]
df_3["Anteil_registered"] = df_3["Anzahl_registered"]/df_3["Anzahl"]

# %%
df_3
# Out:
#       datetime  Anzahl  Anzahl_registered  Anteil_registered
# 0   2020-01-05    1786               1324           0.741321
# 1   2020-01-12    9408               8740           0.928997
# 2   2020-01-19    9025               8351           0.925319
# 3   2020-01-26    7784               7283           0.935637
# 4   2020-02-02   10340               9391           0.908221
# ..         ...     ...                ...                ...
# 101 2021-12-12   41785              37653           0.901113
# 102 2021-12-19   35966              32886           0.914364
# 103 2021-12-26   31871              29080           0.912428
# 104 2022-01-02   32812              29714           0.905583
# 105 2022-01-09    6302               5927           0.940495
#
# [106 rows x 4 columns]

# %%
df_3.corr()
# Out:
#                      Anzahl  Anzahl_registered  Anteil_registered
# Anzahl             1.000000           0.989568          -0.431213
# Anzahl_registered  0.989568           1.000000          -0.312357
# Anteil_registered -0.431213          -0.312357           1.000000

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

# %%
fig.add_trace(
    go.Scatter(x=df_3["datetime"],y=df_3["Anteil_registered"],name="Anteil an registered customer"),
    secondary_y= False
)

# %%
fig.add_trace(
    go.Scatter(x=df_2["datetime"],y=df_2["registered_customer"],name="Anzahl an AUsleihen am Tag"),
    secondary_y= True
)

# %%
subfig = make_subplots(specs=[[{"secondary_y": True}]])

# %%
fig1 = px.scatter(df_3,x="datetime",y="Anteil_registered")

# %%
fig2 = px.scatter(df_3,x="datetime",y="Anzahl")

# %% [markdown]
# temperatur quantile
# und wetter
# gruppen von leuten
# chiquadrat auf wochenende und wetter

# %%
px.scatter(df_3,x="datetime",y="Anzahl",facet_row="Anteil_registered")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\paulh\Desktop\Küppers Projekt1\K-ppers-Projekt1-1\Paul\Spikes.ipynb Zelle 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/paulh/Desktop/K%C3%BCppers%20Projekt1/K-ppers-Projekt1-1/Paul/Spikes.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> px.scatter(df_3,x="datetime",y="Anzahl",facet_row="Anteil_registered")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\express\_chart_types.py:66, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\express\_core.py:2226, in make_figure(args, constructor, trace_patch, layout_patch)
#    2223 if args.get("marginal_y") is not None:
#    2224     ncols += 1
# -> 2226 fig = init_figure(
#    2227     args, subplot_type, frame_list, nrows, ncols, col_labels, row_labels
#    2228 )
#    2230 # Position traces in subplots
#    2231 for frame in frame_list:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\express\_core.py:2370, in init_figure(args, subplot_type, frame_list, nrows, ncols, col_labels, row_labels)
#    2368 except ValueError as e:
#    2369     _spacing_error_translator(e, "Horizontal", "facet_col_spacing")
# -> 2370     _spacing_error_translator(e, "Vertical", "facet_row_spacing")
#    2372 # Remove explicit font size of row/col titles so template can take over
#    2373 for annot in fig.layout.annotations:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\express\_core.py:2349, in init_figure.<locals>._spacing_error_translator(e, direction, facet_arg)
#    2341 if ("%s spacing" % (direction,)) in e.args[0]:
#    2342     e.args = (
#    2343         e.args[0]
#    2344         + """
#    (...)
#    2347         ),
#    2348     )
# -> 2349     raise e
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\express\_core.py:2353, in init_figure(args, subplot_type, frame_list, nrows, ncols, col_labels, row_labels)
#    2351 # Create figure with subplots
#    2352 try:
# -> 2353     fig = make_subplots(
#    2354         rows=nrows,
#    2355         cols=ncols,
#    2356         specs=specs,
#    2357         shared_xaxes="all",
#    2358         shared_yaxes="all",
#    2359         row_titles=[] if facet_col_wrap else list(reversed(row_labels)),
#    2360         column_titles=[] if facet_col_wrap else col_labels,
#    2361         subplot_titles=subplot_labels if facet_col_wrap else [],
#    2362         horizontal_spacing=horizontal_spacing,
#    2363         vertical_spacing=vertical_spacing,
#    2364         row_heights=row_heights,
#    2365         column_widths=column_widths,
#    2366         start_cell="bottom-left",
#    2367     )
#    2368 except ValueError as e:
#    2369     _spacing_error_translator(e, "Horizontal", "facet_col_spacing")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\_subplots.py:567, in make_subplots(rows, cols, shared_xaxes, shared_yaxes, start_cell, print_grid, horizontal_spacing, vertical_spacing, subplot_titles, column_widths, row_heights, specs, insets, column_titles, row_titles, x_title, y_title, figure, **kwargs)
#     565         vertical_spacing = 0.3 / rows
#     566 # check vertical_spacing can be satisfied:
# --> 567 _check_hv_spacing(rows, vertical_spacing, "Vertical", "rows", "rows")
#     569 # ### subplot titles ###
#     570 if subplot_titles is None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\_subplots.py:540, in make_subplots.<locals>._check_hv_spacing(dimsize, spacing, name, dimvarname, dimname)
#     538         max_spacing = 1.0 / float(dimsize - 1)
#     539         if spacing > max_spacing:
# --> 540             raise ValueError(
#     541                 """{name} spacing cannot be greater than (1 / ({dimvarname} - 1)) = {max_spacing:f}.
#     542 The resulting plot would have {dimsize} {dimname} ({dimvarname}={dimsize}).""".format(
#     543                     dimvarname=dimvarname,
#     544                     name=name,
#     545                     dimname=dimname,
#     546                     max_spacing=max_spacing,
#     547                     dimsize=dimsize,
#     548                 )
#     549             )
#
# ValueError: Vertical spacing cannot be greater than (1 / (rows - 1)) = 0.009524.
# The resulting plot would have 106 rows (rows=106).
# Use the facet_row_spacing argument to adjust this spacing.
